# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
aid = pd.read_csv("/content/aid-effectiveness_lka (1).csv")
aid
# Out:
#        Country Name   Country ISO3        Year  \
# 0     #country+name  #country+code  #date+year
# 1         Sri Lanka            LKA        2022
# 2         Sri Lanka            LKA        2021
# 3         Sri Lanka            LKA        2020
# 4         Sri Lanka            LKA        2019
# ...             ...            ...         ...
# 2646      Sri Lanka            LKA        1964
# 2647      Sri Lanka            LKA        1963
# 2648      Sri Lanka            LKA        1962
# 2649      Sri Lanka            LKA        1961
# 2650      Sri Lanka            LKA        1960
#
#                                          Indicator Name     Indicator Code  \
# 0                                       #indicator+name    #indicator+code
# 1     Grants, excluding technical cooperation (BoP, ...  BX.GRT.EXTA.CD.WD
# 2     Grants, excluding technical cooperation (BoP, ...  BX.GRT.EXTA.CD.WD
# 3     Grants, excluding technical cooperation (BoP, ...  BX.GRT.EXTA.CD.WD
# ...

# %%
aid.columns
# Out:
# Index(['Country Name', 'Country ISO3', 'Year', 'Indicator Name',
#        'Indicator Code', 'Value'],
#       dtype='object')

# %%
aid.shape
# Out:
# (2651, 6)

# %%
aid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2651 entries, 0 to 2650
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    2651 non-null   object
#  1   Country ISO3    2651 non-null   object
#  2   Year            2651 non-null   object
#  3   Indicator Name  2651 non-null   object
#  4   Indicator Code  2651 non-null   object
#  5   Value           2651 non-null   object
# dtypes: object(6)
# memory usage: 124.4+ KB

# %%
aid.describe()
# Out:
#        Country Name Country ISO3  Year Indicator Name Indicator Code Value
# count          2651         2651  2651           2651           2651  2651
# unique            2            2    66             67             67  1892
# top       Sri Lanka          LKA  2016  Net migration    SM.POP.NETM   0.1
# freq           2650         2650    60             65             65    33

# %%
missing_values = aid.isnull().sum()
missing_values
# Out:
# Country Name      0
# Country ISO3      0
# Year              0
# Indicator Name    0
# Indicator Code    0
# Value             0
# dtype: int64

# %%
duplicated_values = aid.duplicated().sum()
duplicated_values
# Out:
# np.int64(0)

# %%
print(f"Number of unique values:{aid['Country Name'].nunique()}")
print(f"Unique values:{aid['Country Name'].unique()}")
# Out:
# Number of unique values:2
# Unique values:['#country+name' 'Sri Lanka']

# %%
print(f"Number of unique values:{aid['Country ISO3'].nunique()}")
print(f"Unique values:{aid['Country ISO3'].unique()}")
# Out:
# Number of unique values:2
# Unique values:['#country+code' 'LKA']

# %%
print(f"Number of unique values:{aid['Year'].nunique()}")
print(f"Unique values:{aid['Year'].unique()}")
# Out:
# Number of unique values:66
# Unique values:['#date+year' '2022' '2021' '2020' '2019' '2018' '2017' '2016' '2015'
#  '2014' '2013' '2012' '2011' '2010' '2009' '2008' '2007' '2006' '2005'
#  '2004' '2003' '2002' '2001' '2000' '1999' '1998' '1997' '1996' '1995'
#  '1994' '1993' '1992' '1991' '1990' '1989' '1988' '1987' '1986' '1985'
#  '1984' '1983' '1982' '1981' '1980' '1979' '1978' '1977' '1976' '1975'
#  '1974' '1973' '1972' '1971' '1970' '1969' '1968' '1967' '1966' '1965'
#  '1964' '1963' '1962' '1961' '1960' '2023' '2024']

# %%
print(f"Number of unique values:{aid['Indicator Name'].nunique()}")
print(f"Unique values:{aid['Indicator Name'].unique()}")
# Out:
# Number of unique values:67
# Unique values:['#indicator+name'
#  'Grants, excluding technical cooperation (BoP, current US$)'
#  'Technical cooperation grants (BoP, current US$)'
#  'Net bilateral aid flows from DAC donors, Australia (current US$)'
#  'Net bilateral aid flows from DAC donors, Austria (current US$)'
#  'Net bilateral aid flows from DAC donors, Belgium (current US$)'
#  'Net bilateral aid flows from DAC donors, Canada (current US$)'
#  'Net bilateral aid flows from DAC donors, European Union institutions (current US$)'
#  'Net bilateral aid flows from DAC donors, Switzerland (current US$)'
#  'Net bilateral aid flows from DAC donors, Czechia (current US$)'
#  'Net bilateral aid flows from DAC donors, Germany (current US$)'
#  'Net bilateral aid flows from DAC donors, Denmark (current US$)'
#  'Net bilateral aid flows from DAC donors, Spain (current US$)'
#  'Net bilateral aid flows from DAC donors, Finland (current US$)'
# ...

# %%
print(f"Number of unique values:{aid['Indicator Code'].nunique()}")
print(f"Unique values:{aid['Indicator Code'].unique()}")
# Out:
# Number of unique values:67
# Unique values:['#indicator+code' 'BX.GRT.EXTA.CD.WD' 'BX.GRT.TECH.CD.WD'
#  'DC.DAC.AUSL.CD' 'DC.DAC.AUTL.CD' 'DC.DAC.BELL.CD' 'DC.DAC.CANL.CD'
#  'DC.DAC.CECL.CD' 'DC.DAC.CHEL.CD' 'DC.DAC.CZEL.CD' 'DC.DAC.DEUL.CD'
#  'DC.DAC.DNKL.CD' 'DC.DAC.ESPL.CD' 'DC.DAC.FINL.CD' 'DC.DAC.FRAL.CD'
#  'DC.DAC.GBRL.CD' 'DC.DAC.GRCL.CD' 'DC.DAC.HUNL.CD' 'DC.DAC.IRLL.CD'
#  'DC.DAC.ISLL.CD' 'DC.DAC.ITAL.CD' 'DC.DAC.JPNL.CD' 'DC.DAC.KORL.CD'
#  'DC.DAC.LUXL.CD' 'DC.DAC.NLDL.CD' 'DC.DAC.NORL.CD' 'DC.DAC.NZLL.CD'
#  'DC.DAC.POLL.CD' 'DC.DAC.PRTL.CD' 'DC.DAC.SVNL.CD' 'DC.DAC.SWEL.CD'
#  'DC.DAC.TOTL.CD' 'DC.DAC.USAL.CD' 'DT.NFL.FAOG.CD' 'DT.NFL.IAEA.CD'
#  'DT.NFL.IFAD.CD' 'DT.NFL.ILOG.CD' 'DT.NFL.UNAI.CD' 'DT.NFL.UNCF.CD'
#  'DT.NFL.UNCR.CD' 'DT.NFL.UNDP.CD' 'DT.NFL.UNFP.CD' 'DT.NFL.UNPB.CD'
#  'DT.NFL.UNTA.CD' 'DT.NFL.WFPG.CD' 'DT.NFL.WHOL.CD' 'DT.ODA.ALLD.CD'
#  'DT.ODA.ALLD.KD' 'DT.ODA.ODAT.CD' 'DT.ODA.ODAT.GI.ZS' 'DT.ODA.ODAT.GN.ZS'
# ...

# %%
print(f"Number of unique values:{aid['Value'].nunique()}")
print(f"Unique values:{aid['Value'].unique()}")
# Out:
# Number of unique values:1892
# Unique values:['#indicator+value+num' '238820000' '242270000' ... '-8909' '-10144'
#  '-12610']

# %%
aid = aid.drop(["Country Name","Country ISO3",], axis = 1)
aid = aid.iloc[1:]
aid
# Out:
#       Year                                     Indicator Name  \
# 1     2022  Grants, excluding technical cooperation (BoP, ...
# 2     2021  Grants, excluding technical cooperation (BoP, ...
# 3     2020  Grants, excluding technical cooperation (BoP, ...
# 4     2019  Grants, excluding technical cooperation (BoP, ...
# 5     2018  Grants, excluding technical cooperation (BoP, ...
# ...    ...                                                ...
# 2646  1964                                      Net migration
# 2647  1963                                      Net migration
# 2648  1962                                      Net migration
# 2649  1961                                      Net migration
# 2650  1960                                      Net migration
#
#          Indicator Code      Value
# 1     BX.GRT.EXTA.CD.WD  238820000
# 2     BX.GRT.EXTA.CD.WD  242270000
# 3     BX.GRT.EXTA.CD.WD  185790000
# 4     BX.GRT.EXTA.CD.WD  163360000
# 5     BX.GRT.EXTA.CD.WD  193260000
# ...

# %%
aid["Value"] = aid["Value"].astype(float).round(2)
aid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2650 entries, 1 to 2650
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            2650 non-null   object
#  1   Indicator Name  2650 non-null   object
#  2   Indicator Code  2650 non-null   object
#  3   Value           2650 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 82.9+ KB

# %%
aid.describe()
# Out:
#               Value
# count  2.650000e+03
# mean   5.650825e+07
# std    1.598728e+08
# min   -2.676300e+08
# 25%    9.535000e+01
# 50%    1.790000e+06
# 75%    1.493000e+07
# max    1.207390e+09

# %%
aid.to_csv("aid effectiveness.csv", index = False)
